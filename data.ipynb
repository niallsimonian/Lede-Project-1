# %%
import requests

# %%
url_main = "https://data.cityofnewyork.us/resource/tg4x-b46p.json"
response_main = requests.get(url_main)
data_main = response_main.json()
data_main
# Out:
# [{'eventid': '691875',
#   'eventtype': 'Shooting Permit',
#   'startdatetime': '2023-01-20T06:00:00.000',
#   'enddatetime': '2023-01-20T22:00:00.000',
#   'enteredon': '2023-01-18T14:34:06.000',
#   'eventagency': "Mayor's Office of Film, Theatre & Broadcasting",
#   'parkingheld': '31 STREET between 47 AVENUE and 48 AVENUE',
#   'borough': 'Queens',
#   'communityboard_s': '2',
#   'policeprecinct_s': '108',
#   'category': 'Television',
#   'subcategoryname': 'Episodic series',
#   'country': 'United States of America',
#   'zipcode_s': '11101'},
#  {'eventid': '691797',
#   'eventtype': 'Shooting Permit',
#   'startdatetime': '2023-01-20T09:00:00.000',
#   'enddatetime': '2023-01-21T01:00:00.000',
#   'enteredon': '2023-01-18T11:48:09.000',
#   'eventagency': "Mayor's Office of Film, Theatre & Broadcasting",
# ...

# %%
n = 0
for x in data_main:
    print(data_main[n]['category'])
    print(data_main[n]['startdatetime'])
    print("---")
    n = n + 1
# Out:
# Television
# 2023-01-20T06:00:00.000
# ---
# Television
# 2023-01-20T09:00:00.000
# ---
# Television
# 2023-01-20T11:30:00.000
# ---
# Television
# 2023-01-20T02:30:00.000
# ---
# Television
# 2023-01-20T13:00:00.000
# ---
# Television
# 2023-01-20T06:00:00.000
# ---
# Television
# 2023-01-20T10:00:00.000
# ---
# Television
# 2023-01-19T10:00:00.000
# ---
# Television
# 2023-01-19T06:00:00.000
# ---
# Television
# 2023-01-20T09:30:00.000
# ---
# Television
# 2023-01-20T06:00:00.000
# ---
# Student
# 2023-01-20T09:00:00.000
# ---
# Television
# 2023-01-19T10:00:00.000
# ---
# Television
# 2023-01-19T06:00:00.000
# ---
# Television
# 2023-01-19T07:00:00.000
# ---
# Television
# 2023-01-19T08:00:00.000
# ---
# Television
# 2023-01-19T09:00:00.000
# ---
# Television
# 2023-01-20T09:00:00.000
# ---
# Television
# 2023-01-19T14:00:00.000
# ---
# Television
# 2023-01-19T08:00:00.000
# ---
# Television
# 2023-01-19T07:00:00.000
# ---
# Television
# 2023-01-19T10:00:00.000
# ---
# Television
# ...
